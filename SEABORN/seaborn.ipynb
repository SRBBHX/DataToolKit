# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
sns.get_dataset_names()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2032.0_x64__qbz5n2kfra8p0\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2032.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1294, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1293 """Send a complete request to the server."""
# -> 1294 self._send_request(method, url, body, headers, encode_chunked)
#
# ...

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.relplot(x="age", y="fare", data=titanic)

# %%
sns.relplot(x=titanic.sex, y=titanic.age)

# %%
sns.relplot(x=titanic.sex, y=titanic.age, kind="line")

# %%
warnings.filterwarnings("ignore")

# %%
sns.countplot(titanic.sex, palette="coolwarm")
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x=tips.total_bill, y=tips.tip)

# %%
sns.relplot(x=tips.total_bill, y=tips.tip, hue=tips.smoker)

# %%
sns.relplot(x=tips.total_bill, y=tips.tip, hue=tips.smoker, style=tips.day, palette="rainbow")

# %%
sns.relplot(x="total_bill",y="tip", data=tips, hue="size")

# %%
sns.relplot(x="total_bill", y="tip", data=tips , hue="size", style="smoker")

# %%
sns.relplot(x="total_bill", y="tip", data=tips, hue= "day", style="smoker", )

# %%
time=np.arange(500, dtype=int)
values= np.random.randn(500).cumsum()
df= pd.DataFrame([time,values], index=["Time(h)", "Value"]).T
df
# Out:
#      Time(h)     Value
# 0        0.0  0.416164
# 1        1.0 -0.644270
# 2        2.0 -2.551943
# 3        3.0 -3.667737
# 4        4.0 -3.834964
# ..       ...       ...
# 495    495.0  6.040584
# 496    496.0  6.515930
# 497    497.0  6.076567
# 498    498.0  6.937389
# 499    499.0  7.553679
#
# [500 rows x 2 columns]

# %%
sns.relplot(x="Time(h)", y="Value", data=df,)

# %%
sns.relplot(x="Time(h)", y="Value", data=df,kind="line")

# %%
sns.relplot(x="Time(h)", y="Value", data=df,kind="line", sort=True)

# %%
fmri=sns.load_dataset("fmri")

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x="timepoint", y="signal",data=fmri)

# %%
sns.relplot(x="timepoint", y="signal",data=fmri,kind="line")

# %%
sns.relplot(x="timepoint", y="signal",data=fmri,kind="line",ci="sd")#confidence interveral :standerd derivation

# %%
sns.relplot(x="timepoint", y="signal",data=fmri,kind="line",ci="sd")

# %%
sns.relplot(x="timepoint", y="signal",data=fmri,kind="line",ci="sd",hue="event")

# %%
sns.relplot(x="timepoint", y="signal",data=fmri,kind="line",ci="sd",hue="event",style="region")

# %%
sns.relplot(x="timepoint", y="signal", data=fmri,kind="line", hue="event", style="region" , marker=True, dashes=False)

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x="total_bill", y="tip",data=tips, hue="smoker", style="size", col="time")

# %%
sns.relplot(x="total_bill", y="tip",data=tips, hue="smoker", style="size", col="size")

# %%
sns.catplot(x="day",y="total_bill", data=tips)

# %%
sns.catplot(x="day", y="total_bill",data=tips, kind="swarm")

# %%
sns.catplot(x="day", y="total_bill",data=tips, kind="box")

# %%
sns.catplot(x="day", y="total_bill",data=tips, kind="boxen",palette="rainbow")

# %%
sns.catplot(x="day", y="total_bill",data=tips, kind="bar",palette="rainbow")

# %%
sns.catplot(x="day", y="total_bill",data=tips, kind="violin",palette="rainbow")

# %%
sns.catplot(x="day", y="total_bill",data=tips, kind="point",palette="rainbow")

# %%
sns.catplot(x="day", y="total_bill",data=tips, kind="strip",palette="rainbow")

# %%
sns.barplot(x="day",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.jointplot(x=tips.total_bill, y=tips.tip)

# %%
sns.jointplot(x=tips.total_bill, y=tips.tip, kind="reg")

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex")

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="kde")

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue="smoker")

# %%
sns.pairplot(tips, hue="size")

# %%
sns.pairplot(tips, hue="day")

# %%
sns.pairplot(tips, hue="size", palette="coolwarm")

# %%
sns.pairplot(tips, hue="day", palette="coolwarm")

# %%
sns.boxplot(x="day", y="total_bill", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(tips, orient="h", palette="rainbow")
# Out:
# <Axes: >

# %%
tips=tips[["total_bill", "tip", "size"]]

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr(),)
# Out:
# <Axes: >

# %%
sns.heatmap(tips.corr(), annot=True)
# Out:
# <Axes: >

# %%
tips=sns.load_dataset("tips")

# %%
sns.countplot(x="day",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x="sex", data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x="total_bill", y="tip", data=tips)

# %%
sns.lmplot(x="total_bill", y="tip", data=tips, height=15, aspect=1.5)
